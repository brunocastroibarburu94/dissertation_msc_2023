# %% [markdown]
# Quandl does not work

# %%
# add Quandl

# %% [markdown]
# # AlphaVantage

# %%
using AlphaVantage
using DataFrames

# %%
data=time_series_intraday("AAPL","1min")

# %%
DataFrame(data["Time Series (1min)"])#["2023-05-26 19:28:00"]
# Out:
# 1×100 DataFrame
#  Row │ 2023-05-26 16:43:00                2023-05-26 16:44:00                2 ⋯
#      │ Dict{String, Any}                  Dict{String, Any}                  D ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Dict{String, Any}("4. close"=>"1…  Dict{String, Any}("4. close"=>"1…  D ⋯
#                                                               98 columns omitted
