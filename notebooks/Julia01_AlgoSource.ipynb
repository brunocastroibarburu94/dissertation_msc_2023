# %% [markdown]
# # Usage of AlgoSource
# AlgoSource is a package for retrieval of financial data, since is not registerd it needs to be added through the GitHub URL by opening a terminal in Julia accessing the REPL mode by typing "]" and then executing
#
# ```julia
# add "https://github.com/brunocastroibarburu94/AlgoSource.jl.git#master"
# ```

# %%
using AlgoSource
# IJulia.clear_output() # We don't want the whole output in the screen, when triggering using AlgoSource Python libraries get updates, is very verbose
# Hello world to test the package
# AlgoSource.greet_your_package_name()
# Out:
# [ Info: Downloading miniconda installer ...
# PREFIX=/root/.julia/conda/3/x86_64
# [ Info: Installing miniconda ...
# Unpacking payload ...
# Extracting _libgcc_mutex-0.1-conda_forge.tar.bz2
# Extracting ca-certificates-2022.12.7-ha878542_0.conda
# Extracting ld_impl_linux-64-2.40-h41732ed_0.conda
# Extracting libstdcxx-ng-12.2.0-h46fd767_19.tar.bz2
# Extracting python_abi-3.10-3_cp310.conda
# Extracting tzdata-2023c-h71feb2d_0.conda
# Extracting libgomp-12.2.0-h65d4601_19.tar.bz2
# Extracting _openmp_mutex-4.5-2_gnu.tar.bz2
# Extracting libgcc-ng-12.2.0-h65d4601_19.tar.bz2
# Extracting bzip2-1.0.8-h7f98852_4.tar.bz2
# Extracting libffi-3.4.2-h7f98852_5.tar.bz2
# Extracting libnsl-2.0.0-h7f98852_0.tar.bz2
# Extracting libuuid-2.38.1-h0b41bf4_0.conda
# Extracting libzlib-1.2.13-h166bdaf_4.tar.bz2
# Extracting ncurses-6.3-h27087fc_1.tar.bz2
# Extracting openssl-3.1.0-h0b41bf4_0.conda
# Extracting xz-5.2.6-h166bdaf_0.tar.bz2
# Extracting libsqlite-3.40.0-h753d276_0.tar.bz2
# Extracting readline-8.2-h8228510_1.conda
# Extracting tk-8.6.12-h27826a3_0.tar.bz2
# Extracting zstd-1.5.2-h3eb15da_6.conda
# Extracting python-3.10.10-he550d4f_0_cpython.conda
# Extracting certifi-2022.12.7-pyhd8ed1ab_0.conda
# Extracting charset-normalizer-3.1.0-pyhd8ed1ab_0.conda
# Extracting colorama-0.4.6-pyhd8ed1ab_0.tar.bz2
# Extracting idna-3.4-pyhd8ed1ab_0.tar.bz2
# Extracting pluggy-1.0.0-pyhd8ed1ab_5.tar.bz2
# Extracting pycosat-0.6.4-py310h5764c6d_1.tar.bz2
# Extracting pycparser-2.21-pyhd8ed1ab_0.tar.bz2
# Extracting pysocks-1.7.1-pyha2e5f31_6.tar.bz2
# Extracting ruamel.yaml.clib-0.2.7-py310h1fa729e_1.conda
# Extracting setuptools-65.6.3-pyhd8ed1ab_0.conda
# Extracting toolz-0.12.0-pyhd8ed1ab_0.tar.bz2
# Extracting wheel-0.40.0-pyhd8ed1ab_0.conda
# Extracting cffi-1.15.1-py310h255011f_3.conda
# Extracting pip-23.0.1-pyhd8ed1ab_0.conda
# Extracting ruamel.yaml-0.17.21-py310h1fa729e_3.conda
# Extracting tqdm-4.65.0-pyhd8ed1ab_1.conda
# Extracting brotlipy-0.7.0-py310h5764c6d_1005.tar.bz2
# Extracting cryptography-40.0.1-py310h34c0648_0.conda
# Extracting zstandard-0.19.0-py310hdeb6495_1.conda
# Extracting conda-package-streaming-0.7.0-pyhd8ed1ab_1.conda
# Extracting pyopenssl-23.1.1-pyhd8ed1ab_0.conda
# Extracting conda-package-handling-2.0.2-pyh38be061_0.conda
# Extracting urllib3-1.26.15-pyhd8ed1ab_0.conda
# Extracting requests-2.28.2-pyhd8ed1ab_1.conda
# Extracting conda-23.1.0-py310hff52083_0.conda
#
# Installing base environment...
#
#
#                                            __
#           __  ______ ___  ____ _____ ___  / /_  ____ _
#          / / / / __ `__ \/ __ `/ __ `__ \/ __ \/ __ `/
#         / /_/ / / / / / / /_/ / / / / / / /_/ / /_/ /
#        / .___/_/ /_/ /_/\__,_/_/ /_/ /_/_.___/\__,_/
#       /_/
#
# Transaction
#
#   Prefix: /root/.julia/conda/3/x86_64
#
#   Updating specs:
#
#    - conda-forge/linux-64::_libgcc_mutex==0.1=conda_forge[md5=d7c89558ba9fa0495403155b64376d81]
#    - conda-forge/linux-64::ca-certificates==2022.12.7=ha878542_0[md5=ff9f73d45c4a07d6f424495288a26080]
#    - conda-forge/linux-64::ld_impl_linux-64==2.40=h41732ed_0[md5=7aca3059a1729aa76c597603f10b0dd3]
#    - conda-forge/linux-64::libstdcxx-ng==12.2.0=h46fd767_19[md5=1030b1f38c129f2634eae026f704fe60]
#    - conda-forge/linux-64::python_abi==3.10=3_cp310[md5=4eb33d14d794b0f4be116443ffed3853]
#    - conda-forge/noarch::tzdata==2023c=h71feb2d_0[md5=939e3e74d8be4dac89ce83b20de2492a]
#    - conda-forge/linux-64::libgomp==12.2.0=h65d4601_19[md5=cedcee7c064c01c403f962c9e8d3c373]
#    - conda-forge/linux-64::_openmp_mutex==4.5=2_gnu[md5=73aaf86a425cc6e73fcf236a5a46396d]
#    - conda-forge/linux-64::libgcc-ng==12.2.0=h65d4601_19[md5=e4c94f80aef025c17ab0828cd85ef535]
#    - conda-forge/linux-64::bzip2==1.0.8=h7f98852_4[md5=a1fd65c7ccbf10880423d82bca54eb54]
#    - conda-forge/linux-64::libffi==3.4.2=h7f98852_5[md5=d645c6d2ac96843a2bfaccd2d62b3ac3]
#    - conda-forge/linux-64::libnsl==2.0.0=h7f98852_0[md5=39b1328babf85c7c3a61636d9cd50206]
#    - conda-forge/linux-64::libuuid==2.38.1=h0b41bf4_0[md5=40b61aab5c7ba9ff276c41cfffe6b80b]
#    - conda-forge/linux-64::libzlib==1.2.13=h166bdaf_4[md5=f3f9de449d32ca9b9c66a22863c96f41]
#    - conda-forge/linux-64::ncurses==6.3=h27087fc_1[md5=4acfc691e64342b9dae57cf2adc63238]
#    - conda-forge/linux-64::openssl==3.1.0=h0b41bf4_0[md5=2d833be81a21128e317325a01326d36f]
#    - conda-forge/linux-64::xz==5.2.6=h166bdaf_0[md5=2161070d867d1b1204ea749c8eec4ef0]
#    - conda-forge/linux-64::libsqlite==3.40.0=h753d276_0[md5=2e5f9a37d487e1019fd4d8113adb2f9f]
#    - conda-forge/linux-64::readline==8.2=h8228510_1[md5=47d31b792659ce70f470b5c82fdfb7a4]
#    - conda-forge/linux-64::tk==8.6.12=h27826a3_0[md5=5b8c42eb62e9fc961af70bdd6a26e168]
#    - conda-forge/linux-64::zstd==1.5.2=h3eb15da_6[md5=6b63daed8feeca47be78f323e793d555]
#    - conda-forge/linux-64::python==3.10.10=he550d4f_0_cpython[md5=de25afc7041c103c7f510c746bb63435]
#    - conda-forge/noarch::certifi==2022.12.7=pyhd8ed1ab_0[md5=fb9addc3db06e56abe03e0e9f21a63e6]
#    - conda-forge/noarch::charset-normalizer==3.1.0=pyhd8ed1ab_0[md5=7fcff9f6f123696e940bda77bd4d6551]
#    - conda-forge/noarch::colorama==0.4.6=pyhd8ed1ab_0[md5=3faab06a954c2a04039983f2c4a50d99]
#    - conda-forge/noarch::idna==3.4=pyhd8ed1ab_0[md5=34272b248891bddccc64479f9a7fffed]
#    - conda-forge/noarch::pluggy==1.0.0=pyhd8ed1ab_5[md5=7d301a0d25f424d96175f810935f0da9]
#    - conda-forge/linux-64::pycosat==0.6.4=py310h5764c6d_1[md5=0e565d732f6660374b45d76761c09b06]
#    - conda-forge/noarch::pycparser==2.21=pyhd8ed1ab_0[md5=076becd9e05608f8dc72757d5f3a91ff]
#    - conda-forge/noarch::pysocks==1.7.1=pyha2e5f31_6[md5=2a7de29fb590ca14b5243c4c812c8025]
#    - conda-forge/linux-64::ruamel.yaml.clib==0.2.7=py310h1fa729e_1[md5=2f9b517412af46255cef5e53a22c264e]
#    - conda-forge/noarch::setuptools==65.6.3=pyhd8ed1ab_0[md5=9600fc9524d3f821e6a6d58c52f5bf5a]
#    - conda-forge/noarch::toolz==0.12.0=pyhd8ed1ab_0[md5=92facfec94bc02d6ccf42e7173831a36]
#    - conda-forge/noarch::wheel==0.40.0=pyhd8ed1ab_0[md5=49bb0d9e60ce1db25e151780331bb5f3]
#    - conda-forge/linux-64::cffi==1.15.1=py310h255011f_3[md5=800596144bb613cd7ac58b80900ce835]
#    - conda-forge/noarch::pip==23.0.1=pyhd8ed1ab_0[md5=8025ca83b8ba5430b640b83917c2a6f7]
#    - conda-forge/linux-64::ruamel.yaml==0.17.21=py310h1fa729e_3[md5=97204ae92b703d74a983db0e6d07d009]
#    - conda-forge/noarch::tqdm==4.65.0=pyhd8ed1ab_1[md5=ed792aff3acb977d09c7013358097f83]
#    - conda-forge/linux-64::brotlipy==0.7.0=py310h5764c6d_1005[md5=87669c3468dff637bbd0363bc0f895cf]
#    - conda-forge/linux-64::cryptography==40.0.1=py310h34c0648_0[md5=deafd9206c2e307874f3777a33cafb79]
#    - conda-forge/linux-64::zstandard==0.19.0=py310hdeb6495_1[md5=2cce1a48e6687f64d371d2e7fc9c7fbf]
#    - conda-forge/noarch::conda-package-streaming==0.7.0=pyhd8ed1ab_1[md5=1a2fa9e53cfbc2e4d9ab21990805a436]
#    - conda-forge/noarch::pyopenssl==23.1.1=pyhd8ed1ab_0[md5=0b34aa3ab7e7ccb1765a03dd9ed29938]
#    - conda-forge/noarch::conda-package-handling==2.0.2=pyh38be061_0[md5=44800e9bd13143292097c65e57323038]
#    - conda-forge/noarch::urllib3==1.26.15=pyhd8ed1ab_0[md5=27db656619a55d727eaf5a6ece3d2fd6]
#    - conda-forge/noarch::requests==2.28.2=pyhd8ed1ab_1[md5=3bfbd6ead1d7299ed46dab3a7bf0bc8c]
#    - conda-forge/linux-64::conda==23.1.0=py310hff52083_0[md5=c2f5cd14bf4a8cc673f66fd9839e6602]
#
#
#   Package                      Version  Build               Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex                  0.1  conda_forge         conda-forge     Cached
#   + _openmp_mutex                  4.5  2_gnu               conda-forge     Cached
#   + brotlipy                     0.7.0  py310h5764c6d_1005  conda-forge     Cached
#   + bzip2                        1.0.8  h7f98852_4          conda-forge     Cached
#   + ca-certificates          2022.12.7  ha878542_0          conda-forge     Cached
#   + certifi                  2022.12.7  pyhd8ed1ab_0        conda-forge     Cached
#   + cffi                        1.15.1  py310h255011f_3     conda-forge     Cached
#   + charset-normalizer           3.1.0  pyhd8ed1ab_0        conda-forge     Cached
#   + colorama                     0.4.6  pyhd8ed1ab_0        conda-forge     Cached
#   + conda                       23.1.0  py310hff52083_0     conda-forge     Cached
#   + conda-package-handling       2.0.2  pyh38be061_0        conda-forge     Cached
#   + conda-package-streaming      0.7.0  pyhd8ed1ab_1        conda-forge     Cached
#   + cryptography                40.0.1  py310h34c0648_0     conda-forge     Cached
#   + idna                           3.4  pyhd8ed1ab_0        conda-forge     Cached
#   + ld_impl_linux-64              2.40  h41732ed_0          conda-forge     Cached
#   + libffi                       3.4.2  h7f98852_5          conda-forge     Cached
#   + libgcc-ng                   12.2.0  h65d4601_19         conda-forge     Cached
#   + libgomp                     12.2.0  h65d4601_19         conda-forge     Cached
#   + libnsl                       2.0.0  h7f98852_0          conda-forge     Cached
#   + libsqlite                   3.40.0  h753d276_0          conda-forge     Cached
#   + libstdcxx-ng                12.2.0  h46fd767_19         conda-forge     Cached
#   + libuuid                     2.38.1  h0b41bf4_0          conda-forge     Cached
#   + libzlib                     1.2.13  h166bdaf_4          conda-forge     Cached
#   + ncurses                        6.3  h27087fc_1          conda-forge     Cached
#   + openssl                      3.1.0  h0b41bf4_0          conda-forge     Cached
#   + pip                         23.0.1  pyhd8ed1ab_0        conda-forge     Cached
#   + pluggy                       1.0.0  pyhd8ed1ab_5        conda-forge     Cached
#   + pycosat                      0.6.4  py310h5764c6d_1     conda-forge     Cached
#   + pycparser                     2.21  pyhd8ed1ab_0        conda-forge     Cached
#   + pyopenssl                   23.1.1  pyhd8ed1ab_0        conda-forge     Cached
#   + pysocks                      1.7.1  pyha2e5f31_6        conda-forge     Cached
#   + python                     3.10.10  he550d4f_0_cpython  conda-forge     Cached
#   + python_abi                    3.10  3_cp310             conda-forge     Cached
#   + readline                       8.2  h8228510_1          conda-forge     Cached
#   + requests                    2.28.2  pyhd8ed1ab_1        conda-forge     Cached
#   + ruamel.yaml                0.17.21  py310h1fa729e_3     conda-forge     Cached
#   + ruamel.yaml.clib             0.2.7  py310h1fa729e_1     conda-forge     Cached
#   + setuptools                  65.6.3  pyhd8ed1ab_0        conda-forge     Cached
#   + tk                          8.6.12  h27826a3_0          conda-forge     Cached
#   + toolz                       0.12.0  pyhd8ed1ab_0        conda-forge     Cached
#   + tqdm                        4.65.0  pyhd8ed1ab_1        conda-forge     Cached
#   + tzdata                       2023c  h71feb2d_0          conda-forge     Cached
#   + urllib3                    1.26.15  pyhd8ed1ab_0        conda-forge     Cached
#   + wheel                       0.40.0  pyhd8ed1ab_0        conda-forge     Cached
#   + xz                           5.2.6  h166bdaf_0          conda-forge     Cached
#   + zstandard                   0.19.0  py310hdeb6495_1     conda-forge     Cached
#   + zstd                         1.5.2  h3eb15da_6          conda-forge     Cached
#
#   Summary:
#
#   Install: 47 packages
#
#   Total download: 0 B
#
# ────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking _libgcc_mutex-0.1-conda_forge
# Linking ca-certificates-2022.12.7-ha878542_0
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking libstdcxx-ng-12.2.0-h46fd767_19
# Linking python_abi-3.10-3_cp310
# Linking tzdata-2023c-h71feb2d_0
# Linking libgomp-12.2.0-h65d4601_19
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-12.2.0-h65d4601_19
# Linking bzip2-1.0.8-h7f98852_4
# Linking libffi-3.4.2-h7f98852_5
# Linking libnsl-2.0.0-h7f98852_0
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libzlib-1.2.13-h166bdaf_4
# Linking ncurses-6.3-h27087fc_1
# Linking openssl-3.1.0-h0b41bf4_0
# Linking xz-5.2.6-h166bdaf_0
# Linking libsqlite-3.40.0-h753d276_0
# Linking readline-8.2-h8228510_1
# Linking tk-8.6.12-h27826a3_0
# Linking zstd-1.5.2-h3eb15da_6
# Linking python-3.10.10-he550d4f_0_cpython
# Linking certifi-2022.12.7-pyhd8ed1ab_0
# Linking charset-normalizer-3.1.0-pyhd8ed1ab_0
# Linking colorama-0.4.6-pyhd8ed1ab_0
# Linking idna-3.4-pyhd8ed1ab_0
# Linking pluggy-1.0.0-pyhd8ed1ab_5
# Linking pycosat-0.6.4-py310h5764c6d_1
# Linking pycparser-2.21-pyhd8ed1ab_0
# Linking pysocks-1.7.1-pyha2e5f31_6
# Linking ruamel.yaml.clib-0.2.7-py310h1fa729e_1
# Linking setuptools-65.6.3-pyhd8ed1ab_0
# Linking toolz-0.12.0-pyhd8ed1ab_0
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking cffi-1.15.1-py310h255011f_3
# Linking pip-23.0.1-pyhd8ed1ab_0
# Linking ruamel.yaml-0.17.21-py310h1fa729e_3
# Linking tqdm-4.65.0-pyhd8ed1ab_1
# Linking brotlipy-0.7.0-py310h5764c6d_1005
# Linking cryptography-40.0.1-py310h34c0648_0
# Linking zstandard-0.19.0-py310hdeb6495_1
# Linking conda-package-streaming-0.7.0-pyhd8ed1ab_1
# Linking pyopenssl-23.1.1-pyhd8ed1ab_0
# Linking conda-package-handling-2.0.2-pyh38be061_0
# Linking urllib3-1.26.15-pyhd8ed1ab_0
# Linking requests-2.28.2-pyhd8ed1ab_1
# Linking conda-23.1.0-py310hff52083_0
# Transaction finished
# installation finished.
# [ Info: Running `conda install -y yfinance` in root environment
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /root/.julia/conda/3/x86_64
#
#   added / updated specs:
#     - yfinance
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     beautifulsoup4-4.12.2      |     pyha770c72_0         112 KB  conda-forge
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     conda-23.5.0               |  py310hff52083_1        1006 KB  conda-forge
#     frozendict-2.3.8           |  py310h2372a71_0          46 KB  conda-forge
#     html5lib-1.1               |     pyh9f0ad1d_0          89 KB  conda-forge
#     icu-72.1                   |       hcb278e6_0        11.4 MB  conda-forge
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     libblas-3.9.0              |16_linux64_openblas          13 KB  conda-forge
#     libcblas-3.9.0             |16_linux64_openblas          13 KB  conda-forge
#     libgfortran-ng-12.2.0      |      h69a702a_19          22 KB  conda-forge
#     libgfortran5-12.2.0        |      h337968e_19         1.8 MB  conda-forge
#     libiconv-1.17              |       h166bdaf_0         1.4 MB  conda-forge
#     liblapack-3.9.0            |16_linux64_openblas          13 KB  conda-forge
#     libopenblas-0.3.21         |pthreads_h78a6416_3        10.1 MB  conda-forge
#     libxml2-2.10.4             |       hfdac1af_0         697 KB  conda-forge
#     libxslt-1.1.37             |       h873f0b0_0         251 KB  conda-forge
#     lxml-4.9.2                 |  py310hbdc0903_0         1.3 MB  conda-forge
#     multitasking-0.0.9         |     pyhd8ed1ab_0          12 KB  conda-forge
#     numpy-1.24.3               |  py310ha4c1d20_0         6.4 MB  conda-forge
#     openssl-3.1.0              |       hd590300_3         2.5 MB  conda-forge
#     packaging-23.1             |     pyhd8ed1ab_0          45 KB  conda-forge
#     pandas-2.0.2               |  py310h7cbd5c2_0        11.6 MB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     python-tzdata-2023.3       |     pyhd8ed1ab_0         140 KB  conda-forge
#     pytz-2023.3                |     pyhd8ed1ab_0         182 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     soupsieve-2.3.2.post1      |     pyhd8ed1ab_0          34 KB  conda-forge
#     webencodings-0.5.1         |             py_1          12 KB  conda-forge
#     yfinance-0.2.18            |     pyhd8ed1ab_0          52 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        50.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   beautifulsoup4     conda-forge/noarch::beautifulsoup4-4.12.2-pyha770c72_0
#   boltons            conda-forge/noarch::boltons-23.0.0-pyhd8ed1ab_0
#   frozendict         conda-forge/linux-64::frozendict-2.3.8-py310h2372a71_0
#   html5lib           conda-forge/noarch::html5lib-1.1-pyh9f0ad1d_0
#   icu                conda-forge/linux-64::icu-72.1-hcb278e6_0
#   jsonpatch          conda-forge/noarch::jsonpatch-1.32-pyhd8ed1ab_0
#   jsonpointer        conda-forge/noarch::jsonpointer-2.0-py_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-16_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.2.0-h69a702a_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.2.0-h337968e_19
#   libiconv           conda-forge/linux-64::libiconv-1.17-h166bdaf_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.21-pthreads_h78a6416_3
#   libxml2            conda-forge/linux-64::libxml2-2.10.4-hfdac1af_0
#   libxslt            conda-forge/linux-64::libxslt-1.1.37-h873f0b0_0
#   lxml               conda-forge/linux-64::lxml-4.9.2-py310hbdc0903_0
#   multitasking       conda-forge/noarch::multitasking-0.0.9-pyhd8ed1ab_0
#   numpy              conda-forge/linux-64::numpy-1.24.3-py310ha4c1d20_0
#   packaging          conda-forge/noarch::packaging-23.1-pyhd8ed1ab_0
#   pandas             conda-forge/linux-64::pandas-2.0.2-py310h7cbd5c2_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2023.3-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2023.3-pyhd8ed1ab_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   soupsieve          conda-forge/noarch::soupsieve-2.3.2.post1-pyhd8ed1ab_0
#   webencodings       conda-forge/noarch::webencodings-0.5.1-py_1
#   yfinance           conda-forge/noarch::yfinance-0.2.18-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.12.7-ha878542_0 --> 2023.5.7-hbcca054_0
#   certifi                            2022.12.7-pyhd8ed1ab_0 --> 2023.5.7-pyhd8ed1ab_0
#   conda                              23.1.0-py310hff52083_0 --> 23.5.0-py310hff52083_1
#   openssl                                  3.1.0-h0b41bf4_0 --> 3.1.0-hd590300_3
#
#
#
# Downloading and Extracting Packages
# python-dateutil-2.8. | 240 KB    |                                      |   0%
# python-tzdata-2023.3 | 140 KB    |                                      |   0%
#
# beautifulsoup4-4.12. | 112 KB    |                                      |   0%
#
#
# libgfortran5-12.2.0  | 1.8 MB    |                                      |   0%
#
#
#
# jsonpointer-2.0      | 9 KB      |                                      |   0%
#
#
#
#
# webencodings-0.5.1   | 12 KB     |                                      |   0%
#
#
#
#
#
# icu-72.1             | 11.4 MB   |                                      |   0%
#
#
#
#
#
#
# multitasking-0.0.9   | 12 KB     |                                      |   0%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   |                                      |   0%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   |                                      |   0%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# appdirs-1.4.4        | 13 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.3.2.post | 34 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozendict-2.3.8     | 46 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.17        | 1.4 MB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lxml-4.9.2           | 1.3 MB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.10.4       | 697 KB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.5.7     | 149 KB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# six-1.16.0           | 14 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 13 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# html5lib-1.1         | 89 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblapack-3.9.0      | 13 KB     |                                      |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | ##3                                  |   7%
#
# python-dateutil-2.8. | 240 KB    | ############################7        |  80%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | 3                                    |   1%
#
#
#
# jsonpointer-2.0      | 9 KB      | #################################### | 100%
#
#
#
# jsonpointer-2.0      | 9 KB      | #################################### | 100%
#
# beautifulsoup4-4.12. | 112 KB    | #########################6           |  71%
# python-tzdata-2023.3 | 140 KB    | ####1                                |  11%
#
#
#
#
# webencodings-0.5.1   | 12 KB     | #################################### | 100%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #9                                   |   5%
#
#
#
#
#
# python-dateutil-2.8. | 240 KB    | #################################### | 100%
#
# beautifulsoup4-4.12. | 112 KB    | #################################### | 100%
#
# beautifulsoup4-4.12. | 112 KB    | #################################### | 100%
# python-tzdata-2023.3 | 140 KB    | #################################### | 100%
#
#
#
#
# webencodings-0.5.1   | 12 KB     | #################################### | 100%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###2                                 |   9%
#
#
#
#
#
# icu-72.1             | 11.4 MB   |                                      |   0%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   |                                      |   0%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | 3                                    |   1%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ######4                              |  18%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | 3                                    |   1%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | 4                                    |   1%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   |                                      |   0%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ########3                            |  23%
# python-tzdata-2023.3 | 140 KB    | #################################### | 100%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | 5                                    |   2%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ##########5                          |  29%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | 6                                    |   2%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | 2                                    |   1%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | 9                                    |   3%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ############1                        |  34%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | 8                                    |   2%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | 3                                    |   1%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #1                                   |   3%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ##############1                      |  39%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #2                                   |   3%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | 8                                    |   2%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #5                                   |   4%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###############7                     |  44%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #4                                   |   4%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #1                                   |   3%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #################6                   |  49%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #7                                   |   5%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #3                                   |   4%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #6                                   |   5%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###################2                 |  53%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #9                                   |   5%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #6                                   |   4%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #7                                   |   5%
#
#
#
#
#
#
# multitasking-0.0.9   | 12 KB     | #################################### | 100%
#
#
#
#
#
#
# multitasking-0.0.9   | 12 KB     | #################################### | 100%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##1                                  |   6%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #8                                   |   5%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ####################8                |  58%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #9                                   |   5%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    |                                      |   0%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##                                   |   6%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##                                   |   6%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ######################1              |  61%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##3                                  |   6%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | 3                                    |   1%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##2                                  |   6%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##5                                  |   7%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | 6                                    |   2%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #######################4             |  65%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##2                                  |   6%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##3                                  |   7%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | 8                                    |   2%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##7                                  |   8%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ########################6            |  69%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##5                                  |   7%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #1                                   |   3%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##5                                  |   7%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##9                                  |   8%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #########################9           |  72%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #3                                   |   4%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##6                                  |   7%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##7                                  |   8%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###                                  |   8%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ##########################9          |  75%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #6                                   |   5%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##8                                  |   8%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##8                                  |   8%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###1                                 |   9%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###########################9         |  78%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##                                   |   6%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##9                                  |   8%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###                                  |   9%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###3                                 |   9%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ############################8        |  80%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##2                                  |   6%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###                                  |   9%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###4                                 |  10%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###2                                 |   9%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##5                                  |   7%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #############################8       |  83%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###2                                 |   9%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###6                                 |  10%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###4                                 |   9%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##7                                  |   8%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ##############################7      |  86%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###3                                 |   9%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###7                                 |  10%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###                                  |   8%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###5                                 |  10%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###############################7     |  88%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###5                                 |  10%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###9                                 |  11%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###3                                 |   9%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ################################7    |  91%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###7                                 |  10%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###6                                 |  10%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####                                 |  11%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###5                                 |  10%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #################################6   |  94%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###9                                 |  11%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###8                                 |  11%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####2                                |  12%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###8                                 |  11%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ##################################6  |  96%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####                                 |  11%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###9                                 |  11%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####3                                |  12%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ####1                                |  11%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | ###################################6 |  99%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####2                                |  12%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ####1                                |  11%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####5                                |  13%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ####3                                |  12%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####4                                |  12%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     | #################################### | 100%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ####3                                |  12%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####6                                |  13%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ####6                                |  13%
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####5                                |  13%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | #########################7           |  72%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ####5                                |  13%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ####9                                |  14%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ####8                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####7                                |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# appdirs-1.4.4        | 13 KB     | #################################### | 100%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #####2                               |  15%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####                                |  14%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ####7                                |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# appdirs-1.4.4        | 13 KB     | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ####9                                |  14%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####1                               |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.3.2.post | 34 KB     | ################9                    |  47%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #####5                               |  16%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ####9                                |  14%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####                                |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.3.2.post | 34 KB     | #################################### | 100%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####3                               |  15%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #####9                               |  16%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####2                               |  15%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####1                               |  14%
#
#
# libgfortran5-12.2.0  | 1.8 MB    | #################################### | 100%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####4                               |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozendict-2.3.8     | 46 KB     | ############5                        |  35%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####4                               |  15%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ######2                              |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# frozendict-2.3.8     | 46 KB     | #################################### | 100%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####3                               |  15%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####6                               |  16%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####5                               |  15%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ######5                              |  18%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####5                               |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | ###1                                 |   9%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #####8                               |  16%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ######8                              |  19%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####7                               |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | ############6                        |  35%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####7                               |  16%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######                               |  17%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #####9                               |  16%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #######                              |  20%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######1                              |  17%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####8                               |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | ######################1              |  61%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######                               |  17%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #######3                             |  20%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######2                              |  17%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #####9                               |  17%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######2                              |  17%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #######5                             |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | ###############################6     |  88%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######4                              |  18%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######1                              |  17%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######4                              |  18%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #######9                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | 5                                    |   2%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######6                              |  18%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######3                              |  18%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######5                              |  18%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ########2                            |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #7                                   |   5%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######4                              |  18%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######7                              |  19%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######7                              |  19%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ########4                            |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ###4                                 |  10%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ######9                              |  19%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######6                              |  18%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ######9                              |  19%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ########7                            |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #####1                               |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytz-2023.3          | 182 KB    | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######                              |  20%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######7                              |  19%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######1                             |  20%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ########9                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ######8                              |  19%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######2                             |  20%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ######9                              |  19%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #########2                           |  26%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######3                             |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ########5                            |  24%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######4                             |  21%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######                              |  20%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #########5                           |  26%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######5                             |  21%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######5                             |  21%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #########7                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ##########3                          |  29%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######2                             |  20%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######6                             |  21%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######7                             |  22%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##########                           |  28%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######7                             |  22%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######3                             |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ############                         |  33%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #######9                             |  22%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##########3                          |  29%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######5                             |  21%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #######9                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #############7                       |  38%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########                             |  22%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######6                             |  21%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##########5                          |  29%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########1                            |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ###############4                     |  43%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########2                            |  23%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######8                             |  22%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ##########8                          |  30%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########2                            |  23%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########4                            |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #################1                   |  48%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #######9                             |  22%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###########                          |  31%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########4                            |  23%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########5                            |  24%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###########3                         |  32%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########1                            |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ##################9                  |  53%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########5                            |  24%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########7                            |  24%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########2                            |  23%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###########6                         |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ####################6                |  57%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########7                            |  24%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########4                            |  23%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ########9                            |  25%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ###########8                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ######################3              |  62%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ########8                            |  25%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ############1                        |  34%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########5                            |  24%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ########################             |  67%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########                            |  25%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########7                            |  24%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ############4                        |  34%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########2                           |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #########################7           |  72%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########1                           |  25%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########8                            |  25%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ############6                        |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ###########################4         |  76%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########4                           |  26%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########2                           |  26%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ########9                            |  25%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | ############9                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | #############################2       |  81%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########5                           |  27%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########4                           |  26%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #########1                           |  25%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #############1                       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ##############################9      |  86%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########7                           |  27%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########5                           |  27%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #########2                           |  26%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #############4                       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ################################6    |  91%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########7                           |  27%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #########9                           |  28%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #########4                           |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.5.0         | 1006 KB   | ##################################3  |  95%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #############7                       |  38%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #########8                           |  27%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##########                           |  28%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #########5                           |  27%
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ############################2        |  78%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #################################### | 100%
#
#
#
#
#
#
#
#
#
# numpy-1.24.3         | 6.4 MB    | #################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ##############8                      |  41%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##########################4          |  74%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###########################3         |  76%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ############################3        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###############7                     |  44%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##########################6          |  74%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###########################5         |  76%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ############################5        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ################4                    |  46%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##########################8          |  74%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###########################7         |  77%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #################                    |  47%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##########################9          |  75%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###########################8         |  77%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ############################8        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #################7                   |  49%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###########################1         |  75%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################         |  78%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################        |  81%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###########################3         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ##################6                  |  52%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################2        |  79%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################2       |  81%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###########################4         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###################5                 |  54%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################4        |  79%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################3       |  82%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###########################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ####################4                |  57%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################6        |  80%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################5       |  82%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###########################8         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #####################3               |  59%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ############################8        |  80%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ######################1              |  62%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #############################        |  81%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ############################         |  78%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #############################8       |  83%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #############################2       |  81%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ############################2        |  79%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #######################              |  64%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #############################4       |  82%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ############################4        |  79%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##############################3      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #######################9             |  67%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #############################6       |  82%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##############################5      |  85%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ########################8            |  69%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #############################8       |  83%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##############################7      |  86%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ############################8        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #########################7           |  72%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###############################      |  86%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############################       |  83%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #############################        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ##########################6          |  74%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###############################2     |  87%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############################2      |  84%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #############################2       |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###########################5         |  76%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###############################4     |  87%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############################4      |  85%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ############################4        |  79%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###############################6     |  88%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############################6      |  85%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #############################6       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #############################2       |  81%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###############################8     |  89%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ##############################1      |  84%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #############################8       |  83%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ################################1    |  89%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###############################      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###############################      |  86%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################       |  83%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ################################3    |  90%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###############################2     |  87%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###############################9     |  89%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ################################5    |  90%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###############################4     |  87%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################3      |  84%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ################################8    |  91%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###############################6     |  88%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################5      |  85%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #################################7   |  94%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###############################8     |  88%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################2   |  92%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################7      |  85%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ##################################6  |  96%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################4   |  93%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##############################9      |  86%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ################################2    |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | ###################################5 |  99%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################6   |  94%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###############################1     |  86%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ################################4    |  90%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################9   |  94%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###############################3     |  87%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ################################6    |  91%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##################################2  |  95%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###############################5     |  88%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##################################5  |  96%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###############################7     |  88%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #################################1   |  92%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ##################################7  |  97%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###############################9     |  89%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #################################4   |  93%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###################################  |  97%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ################################1    |  89%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #################################6   |  94%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###################################3 |  98%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ################################4    |  90%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #################################9   |  94%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###################################6 |  99%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ################################6    |  91%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##################################1  |  95%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | ###################################9 | 100%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##################################4  |  96%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ################################9    |  91%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ##################################7  |  97%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #################################2   |  92%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###################################1 |  98%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #################################5   |  93%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###################################4 |  98%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #################################8   |  94%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | ###################################7 |  99%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##################################2  |  95%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ##################################6  |  96%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###################################1 |  98%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | ###################################8 |  99%
#
#
#
#
#
# icu-72.1             | 11.4 MB   | #################################### | 100%
#
#
#
#
#
#
#
# pandas-2.0.2         | 11.6 MB   | #################################### | 100%
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | #################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ### Importing data from Yahoo Finance

# %%
using CSV, DataFrames

# %%
ticker = ["AAPL", "BA", "KO", "GOOGL", "DIS", "XOM"]
# stocks = AlgoSource.yfinance.download(ticker;:start=>"2012-01-01",:end=>"2012-02-01")
df = AlgoSource.YFinance.interday_data(ticker,"2012-01-01","2012-02-01")
# csv_data=CSV.read(IOBuffer(stocks.to_csv()), DataFrame;header=[1,2,3])
# Clean data and present
# names(csv_data) # Obtain Column names
# size(csv_data)  # Obtain number of rows/columns

println("")
println("Columns extracted: $(size(df)[2])")
println("Rows extracted: $(size(df)[1])")
# _name_cleaner(x)=strip(replace(replace(x,r"Column[0-9_]"=>"") , r"[0-9]"=>""),'_')
# rename!(_name_cleaner, csv_data)
df
# Out:
# [*********************100%***********************]  6 of 6 completed
# Columns extracted: 37
# Rows extracted: 20
# 20×37 DataFrame
#  Row │ Date        Adj Close_AAPL  Adj Close_BA  Adj Close_DIS  Adj Close_GOOG ⋯
#      │ Date        Float64         Float64       Float64        Float64        ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2012-01-03         12.4829       60.7311        34.3006          16.651 ⋯
#    2 │ 2012-01-04         12.55         60.8211        34.7841          16.723
#    3 │ 2012-01-05         12.6893       60.1665        35.3661          16.491
#    4 │ 2012-01-06         12.822        60.5347        35.7332          16.266
#    5 │ 2012-01-09         12.8017       60.9847        35.5899          15.577 ⋯
#    6 │ 2012-01-10         12.8475       61.3693        35.4825          15.594
#    7 │ 2012-01-11         12.8265       61.1566        34.6498          15.664
#    8 │ 2012-01-12         12.7913       61.7866        34.6767          15.756
#    9 │ 2012-01-13         12.7434       61.042         34.3812          15.640 ⋯
#   10 │ 2012-01-17         12.8918       61.5657        34.4528          15.730
#   11 │ 2012-01-18         13.0257       61.4184        34.9363          15.838
#   12 │ 2012-01-19         12.9844       61.8276        35.3123          16.005
#   13 │ 2012-01-20         12.7582       61.7948        35.196           14.664 ⋯
#   14 │ 2012-01-23         12.9741       61.7866        35.1422          14.652
#   15 │ 2012-01-24         12.7616       61.6639        35.1422          14.537
#   16 │ 2012-01-25         13.5584       62.0403        35.4198          14.251
#   17 │ 2012-01-26         13.4968       61.623         35.2318          14.216 ⋯
#   18 │ 2012-01-27         13.5772       61.0011        35.1422          14.514
#   19 │ 2012-01-30         13.7512       60.682         34.9095          14.456
#   20 │ 2012-01-31         13.8565       60.6984        34.8289          14.517
#                                                               33 columns omitted

# %% [markdown]
# ### Statistics calculations

# %%
using Statistics

# %%
# Basic Statistics Figures
m1=mean(df[:,:Close_AAPL]) # Mean of Close price of AAPL
s1=std(df[:,:Close_AAPL]) # Standard deviation of Close price of AAPL
v1=var(df[:,:Close_AAPL]) # Variance deviation of Close price of AAPL
println("Mean Close price for Apple (AAPL) in Jan 2012: $(mean(df[:,:Close_AAPL]))")
println("Standard Deviation of Close price for Apple (AAPL) in Jan 2012: $s1")
println("Variance of Close price for Apple (AAPL) in Jan 2012: $v1")
# Out:
# Mean Close price for Apple (AAPL) in Jan 2012: 15.3063570022583
# Standard Deviation of Close price for Apple (AAPL) in Jan 2012: 0.47650632674773596
# Variance of Close price for Apple (AAPL) in Jan 2012: 0.22705827943062012
